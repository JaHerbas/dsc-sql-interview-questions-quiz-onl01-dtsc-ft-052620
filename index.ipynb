# %% [markdown]
# # SQL Interview Questions  - Quiz
#
#
# ## Introduction
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# What are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
#
# TEXT, INTEGER, REAL, BLOB
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
#
# The relationship between these two is that the foreign key is a column or a set of columns in one table that references the primary key in different table, and the primary key is the unique identifier of a record in one table.
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
#
# There are basically three types of relationship entities in an SQL database, these are:
#
# 1.	One-to-One: when each record of one table is related to only one record of the other table (I don’t remember if we saw this one in this section though, I read about it online)
#
# 2.	One-to-Many or Many-to-One: this relationship exists when each record of one table can be related to one or more than one record of the other table. The Many-to-One relationship is a One-to-Many seeing on a different angle
#
# 3.	Many-to-Many: this is when each record of the first table can be related to one or more than one record of the second table and a single record of the second tab  ne related to one or more than one record of the first table.
#
#
# _______________________________________________________________________________________________________________________________
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
#
# There are many types of JOINs but the ones that sqlite supports are JOIN, which is an INNER JOIN and LEFT JOIN.
#
# The JOIN is basically the part that is intercepted between both tables (area in common), and thee LEFT JOIN is the same with the difference that is also returns the records from the left table, so intercepted areas plus left table records
#
# _______________________________________________________________________________________________________________________________
#
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
#
# The GROUP DATA function aggregates data by using aggregate functions such as COUNT, AVG, SUM, MAX and others.
# _______________________________________________________________________________________________________________________________
#
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
#
# The associative entities or JOIN tables are tables that sit between the other two tables of the many-to-many JOINs.
#
# The objective of these entities is to store a record of the combination of the other two tables
#
# _______________________________________________________________________________________________________________________________
#
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
